# %% [markdown]
# # Load csv (user data) and parse it after detecting bank
# Get user csv data for bank data, then detect the bank from it, and parse the fields into a normal form with columns
#
#     Date | Day | Month | Year | Weekday | Amount | Description | Bank | Merchant | Suburb | Latitute | Longitude

# %% [markdown]
# ## All python imports and globals

# %%
# %matplotlib inline
import bank_csv_parser as bp

DATASET_FILE_CBA ='../data/CBA.csv'
DATASET_FILE_BENDIGO ='../data/Bendigo.csv'
DATASET_FILE_ANZ ='../data/ANZ.csv'

# %% [markdown]
# ## Load CBA and display it

# %%
cbaDf = bp.loadAndNormalize(DATASET_FILE_CBA)
cbaDf[1]
# Out:
#          Date  Day  Month  Year  Weekday  Amount  \
# 0  2017-09-27   27      9  2017        2  -40.85
# 1  2017-09-27   27      9  2017        2   -6.50
# 2  2017-09-27   27      9  2017        2   -4.00
# 3  2017-09-27   27      9  2017        2  -10.00
# 4  2017-09-27   27      9  2017        2   -0.80
# 5  2017-09-27   27      9  2017        2 -430.00
# 6  2017-09-27   27      9  2017        2   -4.00
# 7  2017-09-26   26      9  2017        1  -59.99
# 8  2017-09-26   26      9  2017        1  -17.85
# 9  2017-09-26   26      9  2017        1  -34.76
# 10 2017-09-26   26      9  2017        1   -9.51
# 11 2017-09-26   26      9  2017        1   -4.00
# 12 2017-09-26   26      9  2017        1   -9.95
# 13 2017-09-26   26      9  2017        1  -27.50
# 14 2017-09-26   26      9  2017        1   -3.95
# 15 2017-09-26   26      9  2017        1   -7.16
# 16 2017-09-26   26      9  2017        1 -485.00
# 17 2017-09-25   25      9  2017        0  -99.95
# ...

# %% [markdown]
# ## Read Bendigo file and display it

# %%
bendigoDf = bp.loadAndNormalize(DATASET_FILE_BENDIGO)
bendigoDf[1]
# Out:
#          Date  Day  Month  Year  Weekday  Amount  \
# 0  2017-10-17   17     10  2017        1  -12.00
# 1  2017-10-17   17     10  2017        1  -29.81
# 2  2017-10-17   17     10  2017        1  -39.76
# 3  2017-10-17   17     10  2017        1   -9.00
# 4  2017-10-17   17     10  2017        1  -68.00
# 5  2017-10-17   17     10  2017        1  -25.20
# 6  2017-10-17   17     10  2017        1   -5.00
# 7  2017-10-17   17     10  2017        1  -59.95
# 8  2017-10-17   17     10  2017        1  -69.95
# 9  2017-10-15   15     10  2017        6  -96.63
# 10 2017-10-15   15     10  2017        6  -16.97
# 11 2017-10-15   15     10  2017        6  -40.00
# 12 2017-10-14   14     10  2017        5  -14.70
# 13 2017-10-14   14     10  2017        5  -13.90
# 14 2017-10-14   14     10  2017        5  -64.58
# 15 2017-10-14   14     10  2017        5  -87.50
# 16 2017-10-14   14     10  2017        5   -4.50
# 17 2017-10-14   14     10  2017        5   -7.10
# ...

# %% [markdown]
# ## Read ANZ file and display it

# %%
anzDf = bp.loadAndNormalize(DATASET_FILE_ANZ)
anzDf[1]
# Out:
#          Date  Day  Month  Year  Weekday  Amount  \
# 0  2017-09-25   25      9  2017        0  -15.14
# 1  2017-09-25   25      9  2017        0 -200.00
# 2  2017-09-25   25      9  2017        0  -15.08
# 3  2017-09-25   25      9  2017        0   -8.90
# 4  2017-09-25   25      9  2017        0  -12.00
# 5  2017-09-25   25      9  2017        0   -7.50
# 6  2017-09-25   25      9  2017        0  -14.50
# 7  2017-09-25   25      9  2017        0   -3.00
# 8  2017-09-25   25      9  2017        0  -29.75
# 9  2017-09-25   25      9  2017        0  -40.00
# 10 2017-09-25   25      9  2017        0   -5.80
# 11 2017-09-25   25      9  2017        0  -15.00
# 12 2017-09-22   22      9  2017        4  -34.00
# 13 2017-09-22   22      9  2017        4  -26.40
# 14 2017-09-22   22      9  2017        4   -8.50
# 15 2017-09-22   22      9  2017        4   -6.10
# 16 2017-09-21   21      9  2017        3  -20.30
# 17 2017-09-21   21      9  2017        3  -11.00
# ...
