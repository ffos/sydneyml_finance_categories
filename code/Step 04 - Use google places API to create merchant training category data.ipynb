# %% [markdown]
# # Create training data for merchant categories
# For this, I have used google places api, to label merchant categories
# In order to do this, make sure google maps api client library is installed:
#
#     pip install -U googlemaps

# %% [markdown]
# ## All python imports and globals

# %%
# %matplotlib inline
import bank_csv_parser as bp
import pandas as pd
import googlemaps
import api_keys as apiKeys
import json
import difflib

DATASET_FILE_CBA ='../data/CBA.csv'
DATASET_FILE_BENDIGO ='../data/Bendigo.csv'
DATASET_FILE_ANZ ='../data/ANZ.csv'

DATASET_OUTPUT_FILE_MERCHANT_CATEGORIES='../data/MerchantCategories.csv'

COL_NAME_MERCHANT='Merchant'
COL_NAME_SUBURB='Suburb'

COL_NAME_GOOGLE_PLACE_NAME='GPlace_Name'
COL_NAME_GOOGLE_PLACE_ID='GPlace_Id'
COL_NAME_GOOGLE_ADDR='GAddr'
COL_NAME_GOOGLE_CAT0='GCat0'
COL_NAME_GOOGLE_CAT1='GCat1'
COL_NAME_GOOGLE_CAT2='GCat2'


#initialize google maps api client
gmaps = googlemaps.Client(key=apiKeys.API_KEY_GOOGLE_PLACES)

# %% [markdown]
# ## Prepare merchant list by combining normalized data from all banks
# Normalize all bank datasets and retain columns with distinct values for:
#
#     Merchant | Suburb
#
# Then, use google places api to extend this to:
#
#     Merchant | Suburb | GPlace_Name | GPlace_Id| GAddr | GCat0 | GCat1 | GCat2
#
#
# Google categories are defined in: https://developers.google.com/places/web-service/supported_types. Some of them wouldn't make sense for our income/expense categorization app. So, only Table1 categories are whitelisted, and from them the following are excluded:
#
#     * establishment

# %%
CATEGORY_WHITELIST = [
    'accounting',
    'airport',
    'amusement_park',
    'aquarium',
    'art_gallery',
    'atm',
    'bakery',
    'bank',
    'bar',
    'beauty_salon',
    'bicycle_store',
    'book_store',
    'bowling_alley',
    'bus_station',
    'cafe',
    'campground',
    'car_dealer',
    'car_rental',
    'car_repair',
    'car_wash',
    'casino',
    'cemetery',
    'church',
    'city_hall',
    'clothing_store',
    'convenience_store',
    'courthouse',
    'dentist',
    'department_store',
    'doctor',
    'electrician',
    'electronics_store',
    'embassy',
    'finance',
    'fire_station',
    'florist',
    'food',
    'funeral_home',
    'furniture_store',
    'gas_station',
    'general_contractor',
    'grocery_or_supermarket',
    'gym',
    'hair_care',
    'hardware_store',
    'health',
    'hindu_temple',
    'home_goods_store',
    'hospital',
    'insurance_agency',
    'jewelry_store',
    'laundry',
    'lawyer',
    'library',
    'liquor_store',
    'local_government_office',
    'locksmith',
    'lodging',
    'meal_delivery',
    'meal_takeaway',
    'mosque',
    'movie_rental',
    'movie_theater',
    'moving_company',
    'museum',
    'night_club',
    'painter',
    'park',
    'parking',
    'pet_store',
    'pharmacy',
    'physiotherapist',
    'place_of_worship',
    'plumber',
    'police',
    'post_office',
    'real_estate_agency',
    'restaurant',
    'roofing_contractor',
    'rv_park',
    'school',
    'shoe_store',
    'shopping_mall',
    'spa',
    'stadium',
    'storage',
    'store',
    'subway_station',
    'synagogue',
    'taxi_stand',
    'train_station',
    'transit_station',
    'travel_agency',
    'university',
    'veterinary_care',
    'zoo'    
]

# %% [markdown]
# ## Combine all merchant and suburb data

# %%
COLS_TO_RETAIN=[COL_NAME_MERCHANT, COL_NAME_SUBURB]
cbaDf = bp.loadAndNormalize(DATASET_FILE_CBA).ix[:,COLS_TO_RETAIN]
bendigoDf = bp.loadAndNormalize(DATASET_FILE_BENDIGO).ix[:,COLS_TO_RETAIN]
anzDf = bp.loadAndNormalize(DATASET_FILE_ANZ).ix[:,COLS_TO_RETAIN]

df = pd.concat([cbaDf, bendigoDf, anzDf])
df.drop_duplicates(subset=COLS_TO_RETAIN, inplace=True)
print df.shape
df.head()
# Out:
# /home/juicebox/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   from ipykernel import kernelapp as app
# /home/juicebox/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   app.launch_new_instance()
# (194, 2)
# /home/juicebox/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#                  Merchant         Suburb
# 0           HARVIN SPICES  HURSTVILLE BC
# 1                 DELISSE         SYDNEY
# 2  SOUTHGATE GROUP AUSTRA         SYDNEY
# 3              Deli Ziosa         SYDNEY
# 5     BING LEE HURSTVILLE  HURSTVILLE BC

# %% [markdown]
# ## Attach Google Places API results
# Call places api, extract resutl and add new columns. When no results found from google, set value to `'UNCATEGORIZED'`.
# Sometimes Google places api returns multiple matches. In such cases, a selection will be made based on the closest match between field `'name'` (from google json) and `Merchant` text.
#
# The google search will use the string combination of `'Merchant'` + `', '` + `'Suburb'`. So, of Merchant is `'DELISSE'` and Suburb is `'SYDNEY'`, the api query will be for `'DELISSE, SYDNEY'` to help Google narrow down the place.
#
# When there is no match for a lengthier string, say Merchant is `'LITTLE INDIA - HARRIS'`, and Suburb is `'HARRIS PARK'`, the search will trim off to the second lengthiest segment of the merchant. In other words:
#
# * First attempt: No results for `LITTLE INDIA - HARRIS, HARRIS PARK`
#     * Second attempt: `LITTLE INDIA, HARRIS PARK`
#         * Third attempt (if second was unsuccessful): `LITTLE, HARRIS PARK`

# %%
LAT_LNG_APPROX_SYDNEY_CENTER=(-33.861720, 151.012569)
def findNearSydney(merchant, suburb):
    resultJson = gmaps.places_nearby(location=LAT_LNG_APPROX_SYDNEY_CENTER,
                       rank_by='distance',
                       keyword='{}, {}'.format(merchant, suburb))
    return resultJson
                                    

def getBestMatch(merchant, jsonResult):
    candidates = {}
    rNames = []
    rName = None
    lastMatch = None
    for r in jsonResult['results']:
        rName = r['name'].encode('utf-8')
        rVicinity = r['vicinity'].encode('utf-8')
        rNameWithVicinity = "{} {}".format(rName, rVicinity)
        rNames.append(rNameWithVicinity)
        types = [t.encode('utf-8') for t in r['types'] if t in CATEGORY_WHITELIST][:3] + [None, None, None]
        types = types[:3]
        candidates[rNameWithVicinity] = (rName, r['place_id'].encode('utf-8'), rVicinity, types)
        lastMatch = candidates[rNameWithVicinity]

    match = lastMatch
    if len(rNames)>1:
        matches = difflib.get_close_matches(merchant, rNames)
        if matches:
            match = candidates[matches[0]]
    if match:
        return match
    else:
        return (rName, None, None, [None, None, None])

    
def getCategories(merchant, suburb):
    uncat = 'UNCATEGORIZED'
    unknown = 'UNKNOWN'
    result = findNearSydney(merchant,suburb)
    if result['status'] == 'ZERO_RESULTS':
        return unknown, unknown, unknown, [uncat, uncat, uncat]    
    bizName, placeId, addr, cats = getBestMatch("{}, {}".format(merchant,suburb), result)
    if not placeId:
        placeId = unknown
    if not addr:
        addr = unknown
    if not cats:
        cats = [uncat, uncat, uncat]
    elif not cats[0]:
        cats[0] = uncat
    elif not cats[1]:
        cats[1] = uncat
    elif not cats[2]:
        cats[2] = uncat
    return bizName, placeId, addr, cats

# %%
litIndia = getCategories('Little India harris', 'harris park')

# %%
delisse = getCategories('Delisse', 'sydney')
delisse
# Out:
# Cats  ['cafe', 'bakery', 'restaurant']
# ('Delisse',
#  'ChIJsWvvmWquEmsR_6P02hd1eGQ',
#  '52 Martin Place, Sydney',
#  ['cafe', 'bakery', 'restaurant'])

# %%
litIndia
# Out:
# ('Little India',
#  'ChIJfZmJoSOjEmsRcOWkBJCreyI',
#  'Harris Park',
#  ['grocery_or_supermarket', 'food', 'store'])

# %%
def addColumnsForPlaces(df):
    def addLastColumn(df, colName, colVal):
        if not colName in df.columns:
            df.insert(len(df.columns), colName, colVal)
    #Create new columns
    addLastColumn(df, COL_NAME_GOOGLE_PLACE_NAME, 'UNKNOWN')
    addLastColumn(df, COL_NAME_GOOGLE_PLACE_ID, 'UNKNOWN')
    addLastColumn(df, COL_NAME_GOOGLE_ADDR, 'UNKNOWN')
    addLastColumn(df, COL_NAME_GOOGLE_CAT0, 'UNCATEGORIZED')
    addLastColumn(df, COL_NAME_GOOGLE_CAT1, 'UNCATEGORIZED')
    addLastColumn(df, COL_NAME_GOOGLE_CAT2, 'UNCATEGORIZED')
    #add values into these columns
    for idx,row in df.iterrows():
        merchant = row[COL_NAME_MERCHANT]
        suburb = row[COL_NAME_SUBURB]
        place = getCategories(merchant, suburb)
        df.at[idx, COL_NAME_GOOGLE_PLACE_NAME] = place[0]
        df.at[idx, COL_NAME_GOOGLE_PLACE_ID] = place[1]
        df.at[idx, COL_NAME_GOOGLE_ADDR] = place[2]
        df.at[idx, COL_NAME_GOOGLE_CAT0] = place[3][0]
        df.at[idx, COL_NAME_GOOGLE_CAT1] = place[3][1]
        df.at[idx, COL_NAME_GOOGLE_CAT2] = place[3][2]
    return df

# %% [markdown]
# Check if it works on a small data-set first

# %%
addColumnsForPlaces(df.head(5))
# Out:
#                  Merchant         Suburb                   GPlace_Name  \
# 0           HARVIN SPICES  HURSTVILLE BC                       UNKNOWN
# 1                 DELISSE         SYDNEY                       Delisse
# 2  SOUTHGATE GROUP AUSTRA         SYDNEY  West End Motor Group Pty Ltd
# 3              Deli Ziosa         SYDNEY                    Deli Ziosa
# 5     BING LEE HURSTVILLE  HURSTVILLE BC           Bing Lee Hurstville
#
#                      GPlace_Id  \
# 0                      UNKNOWN
# 1  ChIJsWvvmWquEmsR_6P02hd1eGQ
# 2  ChIJ8QmHpuaYEmsRMprnJNboLQo
# 3  ChIJE4-sEUCuEmsRSmjjt4PXDlE
# 5  ChIJoyx_8aK5EmsR-GUkvCsLgTc
#
#                                                GAddr              GCat0  \
# 0                                            UNKNOWN      UNCATEGORIZED
# 1                            52 Martin Place, Sydney               cafe
# 2                                          Blacktown         car_dealer
# 3  Shop 6.17, MLC Food Court, 19/21 Martin Place,...      meal_takeaway
# 5                      3/124 Forest Road, Hurstville  electronics_store
#
#               GCat1          GCat2
# 0     UNCATEGORIZED  UNCATEGORIZED
# 1            bakery     restaurant
# 2             store  UNCATEGORIZED
# 3        restaurant           food
# 5  home_goods_store          store

# %% [markdown]
# ### Transform entire dataset
# I ran into an strange issue where values were misaligned when running transformation on the entire set. So, I am going to split them into groups and update in small batches

# %%
totalSize = len(df)
start = 0
batchSize = 10
transformedBatches = []
while(start<totalSize):
    end = start + batchSize
    batch = df[start:end]
    transformedBatches.append(addColumnsForPlaces(batch))
    start = end
    
transformed = pd.concat(transformedBatches)

# %% [markdown]
# ## Eyeballing results to make sure they make some sense

# %%
transformed[:]
# Out:
#                                              Merchant         Suburb  \
# 0                                       HARVIN SPICES  HURSTVILLE BC
# 1                                             DELISSE         SYDNEY
# 2                              SOUTHGATE GROUP AUSTRA         SYDNEY
# 3                                          Deli Ziosa         SYDNEY
# 5                                 BING LEE HURSTVILLE  HURSTVILLE BC
# 6                                  LA CANTINA ON KENT         SYDNEY
# 7   DIRECT DEBIT 142619 TPG INTERNET DH9Q0HB22EP03...        UNKNOWN
# 8                LUO  SONG CHICKEN QPS PEAKHURST  AUS        UNKNOWN
# 9                                 PLINE PH SUTHERLAND     SUTHERLAND
# 10           UBER TRIP WJAQC HELPU 14518236738 AU AUS        UNKNOWN
# 12                                   JB HI FI MIRANDA        MIRANDA
# 13                                         COLES 4789     SUTHERLAND
# 14                             PHARMACY DEPOT HURSQPS  HURSTVILLE BC
# 15                             ROMEOS FOODHALL SUTHER     SUTHERLAND
# 16  TRANSFER TO OTHER BANK NETBANK RENT PRESIDENT AVE        UNKNOWN
# 17  DIRECT DEBIT 142619 TPG INTERNET DH9M1IFK4EH03...        UNKNOWN
# 18   WDL ATM CBA ATM  WYNYARD A      NSW 200901   AUS        UNKNOWN
# 19                     LONGO GROUP PTY LTD GYMEA  AUS        UNKNOWN
# 20                                 PRICERIGHT VARIETY     SUTHERLAND
# 22                              SQ WHITE HORSE COFFEE     SUTHERLAND
# 24                                          CAFE 2232     SUTHERLAND
# 26                                  TRANSPORT FOR NSW         SYDNEY
# 27                             GUZMAN Y GOMEZ MLC QPS         SYDNEY
# 28             DIRECT DEBIT 119218 VODAFONE T3D11E51E        UNKNOWN
# 29                                        Crafty Cuts         SYDNEY
# 31           UBER TRIP IUFLJ HELPU 14518236738 AU AUS        UNKNOWN
# 35                               POST   SUTHERLAND PO     SUTHERLAND
# 36                                  FORTUNATO  CO P L     SUTHERLAND
# 37                               JUST FALAFEL CENTRAL      HAYMARKET
# 38                                          SUSHI HUB       BROADWAY
# ..                                                ...            ...
# 47                   ENERGYAUSTRALIA PTY LT MELBOURNE        UNKNOWN
# 49                                             GG 151     CASTLECRAG
# 50                                      BEKYA GATEWAY         SYDNEY
# 54                                 Benchmark Espresso         SYDNEY
# 56                                       DIN TAI FUNG         SYDNEY
# 57                            PAYMENT THANKYOU 261068        UNKNOWN
# 59                  HARBOURVIEW TAKEAWAY SHELLHARBOUR        UNKNOWN
# 61                                     BEAN CONNECTED         SYDNEY
# 65                               TPG Internet PTY LTD     NORTH RYDE
# 66                                   FANG FAN PTY LTD         SYDNEY
# 67                                 LUNEBURGER PTY LTD         SYDNEY
# 68                        AIRASIA X ON5IGD PAYPAL COM        UNKNOWN
# 69                                    DESHI GROCERIES       ASHFIELD
# 73                           HJ MARULAN NORTH MARULAN        UNKNOWN
# 74                       PANTANOS BAR  GRILL BATHURST        UNKNOWN
# 75                                Grounds of The City         SYDNEY
# 76                  BP EXP MARULAN 2330 MARULAN NORTH        UNKNOWN
# 77                              SHELL TOLLAND TOLLAND        UNKNOWN
# 78                                                            DRIVER
# 79                            DONUT KING BCC BATHURST        UNKNOWN
# 80                              NEWMANS FUELS BLAYNEY        UNKNOWN
# 81                           WOOLWORTHS 1167 BATHURST        UNKNOWN
# 82                                       7ELEVEN 2201        BURWOOD
# 83                                       ENFES KEBABS         SYDNEY
# 88                                 Indian Street Food         SYDNEY
# 91                                                BBC   WORLD SQUARE
# 94                                                THE      EMUNGALAN
# 97                                      QUAY PHARMACY         SYDNEY
# 98                                          QT SYDNEY         SYDNEY
# 99                                  URBAN ARTISANS PL       ASHFIELD
#
#                               GPlace_Name                    GPlace_Id  \
# 0                                 UNKNOWN                      UNKNOWN
# 1                                 Delisse  ChIJsWvvmWquEmsR_6P02hd1eGQ
# 2            West End Motor Group Pty Ltd  ChIJ8QmHpuaYEmsRMprnJNboLQo
# 3                              Deli Ziosa  ChIJE4-sEUCuEmsRSmjjt4PXDlE
# 5                                 UNKNOWN                      UNKNOWN
# 6            La Cantina Café North Sydney  ChIJU1q2xOyuEmsRUs023sEMv00
# 7                                 UNKNOWN                      UNKNOWN
# 8                                 UNKNOWN                      UNKNOWN
# 9          Priceline Pharmacy Interchange  ChIJSe6UidOoEmsRbVGylc3c6vk
# 10                                UNKNOWN                      UNKNOWN
# 12                       JB Hi-Fi Miranda  ChIJiaA5U5vHEmsREPFXglmojcU
# 13                     Coles Supermarkets  ChIJI-V7O0jHEmsRLYuA_QQYWVM
# 14                                UNKNOWN                      UNKNOWN
# 15        Romeos IGA Food Hall Sutherland  ChIJj3jB9kfHEmsR_ul1DArSB5s
# 16                                UNKNOWN                      UNKNOWN
# 17                                UNKNOWN                      UNKNOWN
# 18                                UNKNOWN                      UNKNOWN
# 19                                UNKNOWN                      UNKNOWN
# 20                             Priceright  ChIJ38frfUjHEmsR4adc-al6bm0
# 22                     White Horse Coffee  ChIJ4eneg0jHEmsR5VC1226oJ7w
# 24                              Cafe 2232  ChIJNwrdV0jHEmsRjm5uq7IzdfI
# 26  Lost Property Transport Sydney Trains  ChIJK9LH7iOuEmsRxJXGAVcr_s4
# 27        Guzman y Gomez Mexican Taqueria  ChIJrT6HsT-uEmsR8d3mJ5DkCKA
# 28                                UNKNOWN                      UNKNOWN
# 29                            Crafty Cuts  ChIJk8tbCECuEmsRES9TzgBsDDI
# 31                                UNKNOWN                      UNKNOWN
# 35                         Australia Post  ChIJXRt3hEjHEmsRdyJ5a0mjrnA
# 36                                UNKNOWN                      UNKNOWN
# 37                            Street Food  ChIJJb7msyauEmsRG318IfuRAe0
# 38               Sushi Hub Sydney Central  ChIJ9SHspiauEmsREv7orwlkA_I
# ..                                    ...                          ...
# 47                                UNKNOWN                      UNKNOWN
# 49                                UNKNOWN                      UNKNOWN
# 50                                  Bekya  ChIJIduJc0KuEmsRz9Kr-USgJus
# 54                     Benchmark Espresso  ChIJLWPB6z6uEmsR7pv0x9tHNu8
# 56                           Din Tai Fung  ChIJpy35S9miEmsR5oS5PSbtkcs
# 57                                UNKNOWN                      UNKNOWN
# 59                                UNKNOWN                      UNKNOWN
# 61                             AMP CENTER  ChIJK_kAwWmuEmsRXrYd-01gGUI
# 65                            TPG Telecom  ChIJ6zDIWD5d1moRfHBO3nzf7c8
# 66                                UNKNOWN                      UNKNOWN
# 67               Luneburger German Bakery  ChIJiaA5U5vHEmsRMfmAGJXCSv0
# 68                                UNKNOWN                      UNKNOWN
# 69                        Deshi Groceries  ChIJxdD_cr26EmsRAs8KX1FpYTA
# 73                                UNKNOWN                      UNKNOWN
# 74                                UNKNOWN                      UNKNOWN
# 75                The Grounds of the City  ChIJ2QUmiz6uEmsRQfMmet7xkzs
# 76                                UNKNOWN                      UNKNOWN
# 77                                UNKNOWN                      UNKNOWN
# 78                     ABC Driving School  ChIJEXhAqZhitAER7Y3arvLsaVA
# 79                                UNKNOWN                      UNKNOWN
# 80                                UNKNOWN                      UNKNOWN
# 81                                UNKNOWN                      UNKNOWN
# 82                       7-Eleven Burwood  ChIJP0ghYs66EmsRzk_8N1w_hFs
# 83                           Enfes Kebabs  ChIJDZpopzCuEmsRfXc9BfpPHaA
# 88                       Bang Street Food  ChIJvVmbPhmuEmsRH0dAPfdKMA8
# 91                           World Square  ChIJmwPYyTyuEmsRX0mvV93VCxs
# 94                                UNKNOWN                      UNKNOWN
# 97                          Quay Pharmacy  ChIJ8dVPLWiuEmsR4E4i17CziKQ
# 98                              QT Sydney  ChIJK6RwVT6uEmsRQ447JSUTGGI
# 99                     The Urban Artisans  ChIJa8p5Ipa6EmsRs27IR7xhkDo
#
#                                                 GAddr                   GCat0  \
# 0                                             UNKNOWN  grocery_or_supermarket
# 1                             52 Martin Place, Sydney                    cafe
# 2                                           Blacktown              car_dealer
# 3   Shop 6.17, MLC Food Court, 19/21 Martin Place,...           meal_takeaway
# 5                                             UNKNOWN           UNCATEGORIZED
# 6                     168 Walker Street, North Sydney                    cafe
# 7                                             UNKNOWN           UNCATEGORIZED
# 8                                             UNKNOWN           UNCATEGORIZED
# 9                   40/436 Victoria Avenue, Chatswood                pharmacy
# 10                                            UNKNOWN           UNCATEGORIZED
# 17  DIRECT DEBIT 142619 TPG INTERNET DH9M1IFK4EH03...        UNKNOWN
# 18   WDL ATM CBA ATM  WYNYARD A      NSW 200901   AUS        UNKNOWN
# 19                     LONGO GROUP PTY LTD GYMEA  AUS        UNKNOWN
# 26                                  TRANSPORT FOR NSW         SYDNEY
# 28             DIRECT DEBIT 119218 VODAFONE T3D11E51E        UNKNOWN
# 31           UBER TRIP IUFLJ HELPU 14518236738 AU AUS        UNKNOWN
# 36                                  FORTUNATO  CO P L     SUTHERLAND
# 41                                DAVID TRACY NSW PTY         SYDNEY
# 42                                         BIG W 0182  HURSTVILLE BC
# 43                                  UBER   TRIP 6VFP2         SYDNEY
# 44                             HOK LAI PTY LTD    QPS      HAYMARKET
# 45                 CTX SYLVANIA HEIGHTS SYLVANIA  AUS        UNKNOWN
# 48                               TASTE OF LEBANON HRS  HURSTVILLE BC
# 52                                      GoGetCarshare      HAYMARKET
# 53           REMOVALIST GROUP PL CHIPPING NORT NS AUS        UNKNOWN
# 58            LAMB  CUMIN AUSTRAL CONDELL PARK NS AUS        UNKNOWN
# 62                        TRUPT PL EDMONDSON PAR  AUS        UNKNOWN
# 64                                  CHEMIST WAREHOUSE  HURSTVILLE BC
# 66                                         CITY BEACH  HURSTVILLE BC
# 67                PATTAN SUPERMARKET HARRIS PARK  AUS        UNKNOWN
# 70                                         BEST  LESS  HURSTVILLE BC
# 71                                  DANCEKOOL PTY LTD      HAYMARKET
# 73                               MIRCHI HURSTVILLE IN  HURSTVILLE BC
# ..                                                ...            ...
# 81                                 The Greens NSW Inc          GLEBE
# 87                                TAXI COMBINED 13330     ALEXANDRIA
# 88                                   JOHNNYS FRESH PL        PYRMONT
# 93                                MYREPUBLIC BROADBAN     ALEXANDRIA
# 95  INTERNATIONAL DAVID ROBINSON 6502043486 2509 U...        UNKNOWN
# 96                                  SUSHIROLL UNSW PL     KENSINGTON
# 5                              DAVID TRACY INVESTMENT         SYDNEY
# 11                                 FOREVER TWENTY ONE      BANKSTOWN
# 15                     HJ CIRCULAR QUAY CIRCULAR QUAY        UNKNOWN
# 26                                                     ALEXANDRIA MC
# 27                             CALTEX CONCORD CONCORD        UNKNOWN
# 29                                TAIMEI BUSINESS PTY       ASHFIELD
# 36                                RMS ETOLL PH 131865     PARRAMATTA
# 47                   ENERGYAUSTRALIA PTY LT MELBOURNE        UNKNOWN
# 49                                             GG 151     CASTLECRAG
# 54                                 Benchmark Espresso         SYDNEY
# 57                            PAYMENT THANKYOU 261068        UNKNOWN
# 59                  HARBOURVIEW TAKEAWAY SHELLHARBOUR        UNKNOWN
# 65                               TPG Internet PTY LTD     NORTH RYDE
# 66                                   FANG FAN PTY LTD         SYDNEY
# 68                        AIRASIA X ON5IGD PAYPAL COM        UNKNOWN
# 73                           HJ MARULAN NORTH MARULAN        UNKNOWN
# 74                       PANTANOS BAR  GRILL BATHURST        UNKNOWN
# 76                  BP EXP MARULAN 2330 MARULAN NORTH        UNKNOWN
# 77                              SHELL TOLLAND TOLLAND        UNKNOWN
# 78                                                            DRIVER
# 79                            DONUT KING BCC BATHURST        UNKNOWN
# 80                              NEWMANS FUELS BLAYNEY        UNKNOWN
# 81                           WOOLWORTHS 1167 BATHURST        UNKNOWN
# 94                                                THE      EMUNGALAN
#
#                               GPlace_Name                    GPlace_Id  \
# 0                                 UNKNOWN                      UNKNOWN
# 5                                 UNKNOWN                      UNKNOWN
# 7                                 UNKNOWN                      UNKNOWN
# 8                                 UNKNOWN                      UNKNOWN
# 10                                UNKNOWN                      UNKNOWN
# 14                                UNKNOWN                      UNKNOWN
# 16                                UNKNOWN                      UNKNOWN
# 17                                UNKNOWN                      UNKNOWN
# 18                                UNKNOWN                      UNKNOWN
# 19                                UNKNOWN                      UNKNOWN
# 26  Lost Property Transport Sydney Trains  ChIJK9LH7iOuEmsRxJXGAVcr_s4
# 28                                UNKNOWN                      UNKNOWN
# 31                                UNKNOWN                      UNKNOWN
# 36                                UNKNOWN                      UNKNOWN
# 41                                UNKNOWN                      UNKNOWN
# 42                                UNKNOWN                      UNKNOWN
# 43                            Uber Sydney  ChIJd29oCNqkEmsRg4kMlo6oK-g
# 44                                UNKNOWN                      UNKNOWN
# 45                                UNKNOWN                      UNKNOWN
# 48                                UNKNOWN                      UNKNOWN
# 52                     GoGet CarShare Pod  ChIJVWxHdyuuEmsROkfOjA4jAK4
# 53                                UNKNOWN                      UNKNOWN
# 58                                UNKNOWN                      UNKNOWN
# 62                                UNKNOWN                      UNKNOWN
# 64                                UNKNOWN                      UNKNOWN
# 66                                UNKNOWN                      UNKNOWN
# 67                                UNKNOWN                      UNKNOWN
# 70                                UNKNOWN                      UNKNOWN
# 71                                UNKNOWN                      UNKNOWN
# 73                                UNKNOWN                      UNKNOWN
# ..                                    ...                          ...
# 81                         The Greens NSW  ChIJIcQFwUqwEmsRnT7E89OmxVA
# 87                         Taxis Combined  ChIJ1zC5d7ixEmsRqRcqJmrNn_E
# 88                                UNKNOWN                      UNKNOWN
# 93                                UNKNOWN                      UNKNOWN
# 95                                UNKNOWN                      UNKNOWN
# 96                                UNKNOWN                      UNKNOWN
# 5                                 UNKNOWN                      UNKNOWN
# 11                                UNKNOWN                      UNKNOWN
# 15                                UNKNOWN                      UNKNOWN
# 26                                UNKNOWN                      UNKNOWN
# 27                                UNKNOWN                      UNKNOWN
# 29                                UNKNOWN                      UNKNOWN
# 36                                UNKNOWN                      UNKNOWN
# 47                                UNKNOWN                      UNKNOWN
# 49                                UNKNOWN                      UNKNOWN
# 54                     Benchmark Espresso  ChIJLWPB6z6uEmsR7pv0x9tHNu8
# 57                                UNKNOWN                      UNKNOWN
# 59                                UNKNOWN                      UNKNOWN
# 65                            TPG Telecom  ChIJ6zDIWD5d1moRfHBO3nzf7c8
# 66                                UNKNOWN                      UNKNOWN
# 68                                UNKNOWN                      UNKNOWN
# 73                                UNKNOWN                      UNKNOWN
# 74                                UNKNOWN                      UNKNOWN
# 76                                UNKNOWN                      UNKNOWN
# 77                                UNKNOWN                      UNKNOWN
# 78                     ABC Driving School  ChIJEXhAqZhitAER7Y3arvLsaVA
# 79                                UNKNOWN                      UNKNOWN
# 80                                UNKNOWN                      UNKNOWN
# 81                                UNKNOWN                      UNKNOWN
# 94                                UNKNOWN                      UNKNOWN
#
#                                 GAddr          GCat0          GCat1  \
# 0                             UNKNOWN  UNCATEGORIZED  UNCATEGORIZED
#